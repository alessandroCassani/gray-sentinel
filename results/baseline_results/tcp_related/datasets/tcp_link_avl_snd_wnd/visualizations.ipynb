# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
from pylab import rcParams
from scipy.stats.stats import pearsonr
from scipy.stats.stats import spearmanr
import seaborn as sns
import statsmodels.api as sm
# Out:
# /tmp/ipykernel_58550/1396264545.py:7: DeprecationWarning: Please import `pearsonr` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.stats.stats import pearsonr
# /tmp/ipykernel_58550/1396264545.py:8: DeprecationWarning: Please import `spearmanr` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.stats.stats import spearmanr

# %%
# Out:
# Numero totale di colonne: 222
# Numero di nomi di colonna unici: 144
#
# Primi 10 nomi di colonna:
# 1. ip1_client_8080_inf
# 2. ip1_client_8080_1k
# 3. ip1_client_8080_10k
# 4. ip1_client_8080_100k
# 5. ip1_client_8080_1M
# 6. ip1_client_8080_10M
# 7. discovery-server_server_8761_inf
# 8. discovery-server_server_8761_1k
# 9. discovery-server_server_8761_10k
# 10. discovery-server_server_8761_100k
#
# Nomi di colonna unici:
# 1. admin-server_client_8080_100k
# 2. admin-server_client_8080_10M
# 3. admin-server_client_8080_10k
# 4. admin-server_client_8080_1M
# 5. admin-server_client_8080_1k
# 6. admin-server_client_8080_inf
# 7. admin-server_client_8081_100k
# 8. admin-server_client_8081_10M
# 9. admin-server_client_8081_10k
# 10. admin-server_client_8081_1M
# 11. admin-server_client_8081_1k
# 12. admin-server_client_8081_inf
# 13. admin-server_client_8082_100k
# 14. admin-server_client_8082_10M
# 15. admin-server_client_8082_10k
# 16. admin-server_client_8082_1M
# 17. admin-server_client_8082_1k
# 18. admin-server_client_8082_inf
# 19. admin-server_client_8083_100k
# 20. admin-server_client_8083_10M
# 21. admin-server_client_8083_10k
# 22. admin-server_client_8083_1M
# 23. admin-server_client_8083_1k
# 24. admin-server_client_8083_inf
# 25. admin-server_client_8084_100k
# 26. admin-server_client_8084_10M
# 27. admin-server_client_8084_10k
# 28. admin-server_client_8084_1M
# 29. admin-server_client_8084_1k
# 30. admin-server_client_8084_inf
# 31. admin-server_client_8761_100k
# 32. admin-server_client_8761_10M
# 33. admin-server_client_8761_10k
# 34. admin-server_client_8761_1M
# 35. admin-server_client_8761_1k
# 36. admin-server_client_8761_inf
# 37. admin-server_client_9090_100k
# 38. admin-server_client_9090_10M
# 39. admin-server_client_9090_10k
# 40. admin-server_client_9090_1M
# 41. admin-server_client_9090_1k
# 42. admin-server_client_9090_inf
# 43. admin-server_server_9090_100k
# 44. admin-server_server_9090_10M
# 45. admin-server_server_9090_10k
# 46. admin-server_server_9090_1M
# 47. admin-server_server_9090_1k
# 48. admin-server_server_9090_inf
# 49. api-gateway_client_8081_100k
# 50. api-gateway_client_8081_10M
# 51. api-gateway_client_8081_10k
# 52. api-gateway_client_8081_1M
# 53. api-gateway_client_8081_1k
# 54. api-gateway_client_8081_inf
# 55. api-gateway_client_8082_100k
# 56. api-gateway_client_8082_10M
# 57. api-gateway_client_8082_10k
# 58. api-gateway_client_8082_1M
# 59. api-gateway_client_8082_1k
# 60. api-gateway_client_8082_inf
# 61. api-gateway_client_8083_100k
# 62. api-gateway_client_8083_10M
# 63. api-gateway_client_8083_10k
# 64. api-gateway_client_8083_1M
# 65. api-gateway_client_8083_1k
# 66. api-gateway_client_8083_inf
# 67. api-gateway_client_8761_100k
# 68. api-gateway_client_8761_10M
# 69. api-gateway_client_8761_10k
# 70. api-gateway_client_8761_1M
# 71. api-gateway_client_8761_1k
# 72. api-gateway_client_8761_inf
# 73. api-gateway_server_8080_100k
# 74. api-gateway_server_8080_10M
# 75. api-gateway_server_8080_10k
# 76. api-gateway_server_8080_1M
# 77. api-gateway_server_8080_1k
# 78. api-gateway_server_8080_inf
# 79. config-server_client_443_100k
# 80. config-server_client_443_10M
# 81. config-server_client_443_10k
# 82. config-server_client_443_1M
# 83. config-server_client_443_1k
# 84. config-server_client_443_inf
# 85. customers-service_client_8761_100k
# 86. customers-service_client_8761_10M
# 87. customers-service_client_8761_10k
# 88. customers-service_client_8761_1M
# 89. customers-service_client_8761_1k
# 90. customers-service_client_8761_inf
# 91. customers-service_server_8081_100k
# 92. customers-service_server_8081_10M
# 93. customers-service_server_8081_10k
# 94. customers-service_server_8081_1M
# 95. customers-service_server_8081_1k
# 96. customers-service_server_8081_inf
# 97. discovery-server_server_8761_100k
# 98. discovery-server_server_8761_10M
# 99. discovery-server_server_8761_10k
# 100. discovery-server_server_8761_1M
# 101. discovery-server_server_8761_1k
# 102. discovery-server_server_8761_inf
# 103. genai-service_client_8761_100k
# 104. genai-service_client_8761_10M
# 105. genai-service_client_8761_10k
# 106. genai-service_client_8761_1M
# 107. genai-service_client_8761_1k
# 108. genai-service_client_8761_inf
# 109. genai-service_server_8084_100k
# 110. genai-service_server_8084_10M
# 111. genai-service_server_8084_10k
# 112. genai-service_server_8084_1M
# 113. genai-service_server_8084_1k
# 114. genai-service_server_8084_inf
# 115. ip1_client_8080_100k
# 116. ip1_client_8080_10M
# 117. ip1_client_8080_10k
# 118. ip1_client_8080_1M
# 119. ip1_client_8080_1k
# 120. ip1_client_8080_inf
# 121. vets-service_client_8761_100k
# 122. vets-service_client_8761_10M
# 123. vets-service_client_8761_10k
# 124. vets-service_client_8761_1M
# 125. vets-service_client_8761_1k
# 126. vets-service_client_8761_inf
# 127. vets-service_server_8083_100k
# 128. vets-service_server_8083_10M
# 129. vets-service_server_8083_10k
# 130. vets-service_server_8083_1M
# 131. vets-service_server_8083_1k
# 132. vets-service_server_8083_inf
# 133. visits-service_client_8761_100k
# 134. visits-service_client_8761_10M
# 135. visits-service_client_8761_10k
# 136. visits-service_client_8761_1M
# 137. visits-service_client_8761_1k
# 138. visits-service_client_8761_inf
# 139. visits-service_server_8082_100k
# 140. visits-service_server_8082_10M
# 141. visits-service_server_8082_10k
# 142. visits-service_server_8082_1M
# 143. visits-service_server_8082_1k
# 144. visits-service_server_8082_inf
