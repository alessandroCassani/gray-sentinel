# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as scipy_stats
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Load all memory datasets
df_mem_util = pd.read_csv("mem_util.csv")
df_mem_cache = pd.read_csv("mem_cache.csv")
df_mem_available = pd.read_csv("mem_available.csv")

df_baseline_mem_util = pd.read_csv("../../baseline/memory related/mem_util.csv")
df_baseline_mem_cache = pd.read_csv("../../baseline/memory related/mem_cache.csv")
df_baseline_mem_available = pd.read_csv("../../baseline/memory related/mem_available.csv")

# Add source labels
df_mem_util["source"] = "NETLOSS"
df_mem_cache["source"] = "NETLOSS"
df_mem_available["source"] = "NETLOSS"

df_baseline_mem_util["source"] = "BASELINE"
df_baseline_mem_cache["source"] = "BASELINE"
df_baseline_mem_available["source"] = "BASELINE"

# Convert to datetime
for df in [df_mem_util, df_mem_cache, df_mem_available, 
           df_baseline_mem_util, df_baseline_mem_cache, df_baseline_mem_available]:
    df["Time"] = pd.to_datetime(df["Time"])

delay = 30
duration = 50

# Synchronize test datasets with baseline timeline
time_offset = df_baseline_mem_util["Time"].min() - df_mem_util["Time"].min()
df_mem_util["Time"] += time_offset
df_mem_cache["Time"] += time_offset
df_mem_available["Time"] += time_offset

# Convert timeline to minutes
all_dfs = [df_mem_util, df_mem_cache, df_mem_available,
           df_baseline_mem_util, df_baseline_mem_cache, df_baseline_mem_available]

for df in all_dfs:
    df["Minutes"] = (df["Time"] - df["Time"].min()).dt.total_seconds() / 60

# ORIGINAL DATASETS DICTIONARY
original_datasets = {
    'Memory Utilization': {'netloss': df_mem_util, 'baseline': df_baseline_mem_util},
    'Memory Cache': {'netloss': df_mem_cache, 'baseline': df_baseline_mem_cache},
    'Memory Available': {'netloss': df_mem_available, 'baseline': df_baseline_mem_available}
}

def add_phase_column(df, delay_minutes, duration_minutes):
    df = df.copy()
    df['phase'] = 'before'  
    df.loc[(df['Minutes'] >= delay_minutes) & (df['Minutes'] <= delay_minutes + duration_minutes), 'phase'] = 'during'  
    df.loc[df['Minutes'] > delay_minutes + duration_minutes, 'phase'] = 'after' 
    return df

def remove_outliers_simple(df, contamination=0.02):
    """Global Isolation Forest for baseline data with improved interpolation"""
    df_clean = df.copy()
    outlier_stats = {}
    
    numeric_cols = [col for col in df.select_dtypes(include=[np.number]).columns 
                   if col not in ['Time', 'Minutes']]
    
    if len(numeric_cols) == 0:
        return df_clean, outlier_stats
    
    # Simple feature matrix - just the raw values
    if len(numeric_cols) == 1:
        feature_matrix = df[numeric_cols[0]].values.reshape(-1, 1)
    else:
        feature_matrix = df[numeric_cols].values
    
    # Fill NaN values
    feature_matrix = pd.DataFrame(feature_matrix).fillna(method='ffill').fillna(method='bfill').values
    
    # Scale and apply Isolation Forest
    scaler = StandardScaler()
    feature_matrix_scaled = scaler.fit_transform(feature_matrix)
    
    iso_forest = IsolationForest(
        contamination=contamination,
        n_estimators=100,
        random_state=42,
        n_jobs=-1
    )
    
    iso_forest.fit(feature_matrix_scaled)
    outlier_predictions = iso_forest.predict(feature_matrix_scaled)
    outlier_mask = outlier_predictions == -1
    
    # Apply outlier removal with improved interpolation
    for col in numeric_cols:
        outlier_stats[col] = {
            'count': outlier_mask.sum(),
            'percentage': (outlier_mask.sum() / len(df[col])) * 100
        }
        
        if outlier_mask.sum() > 0:
            # Store original values for context-aware interpolation
            original_series = df_clean[col].copy()
            
            # Mark outliers as NaN
            df_clean.loc[outlier_mask, col] = np.nan
            
            # Use polynomial interpolation to better preserve patterns
            try:
                df_clean[col] = df_clean[col].interpolate(method='polynomial', order=2, limit_direction='both')
            except:
                df_clean[col] = df_clean[col].interpolate(method='linear', limit_direction='both')
            
            # If interpolation fails, fallback to linear
            if df_clean[col].isna().any():
                df_clean[col] = df_clean[col].interpolate(method='linear', limit_direction='both')
            
            # Final fallback: forward/backward fill
            if df_clean[col].isna().any():
                df_clean[col] = df_clean[col].fillna(method='ffill').fillna(method='bfill')

    outlier_stats['_summary'] = {
        'total_outliers': outlier_mask.sum(),
        'contamination_rate': contamination,
        'method': 'simple_isolation_forest'
    }
    
    return df_clean, outlier_stats

def remove_outliers_phase_aware(df, delay_minutes=30, duration_minutes=50):
    """Per-phase Isolation Forest for test data with chaos-preserving interpolation"""
    df_clean = df.copy()
    df_clean = add_phase_column(df_clean, delay_minutes, duration_minutes)
    
    numeric_cols = [col for col in df.select_dtypes(include=[np.number]).columns 
                   if col not in ['Time', 'Minutes']]
    outlier_stats = {}
    
    if len(numeric_cols) == 0:
        return df_clean, outlier_stats
    
    # Define buffer zones around chaos period
    buffer_minutes = 2
    chaos_start = delay_minutes
    chaos_end = delay_minutes + duration_minutes
    
    # Very conservative contamination rates
    phase_contamination = {
        'before': 0.02,   # Normal baseline cleaning  
        'during': 0.001,  # EXTREMELY conservative during chaos
        'after': 0.03     # Slightly higher for recovery
    }
    
    total_outliers = 0
    
    for phase in ['before', 'during', 'after']:
        phase_mask = df_clean['phase'] == phase
        phase_data = df_clean[phase_mask]
        
        if len(phase_data) < 10:
            continue
        
        # Exclude border zones from training data for each phase
        if phase == 'before':
            training_mask = phase_data['Minutes'] < (chaos_start - buffer_minutes)
        elif phase == 'during':
            training_mask = (
                (phase_data['Minutes'] > (chaos_start + buffer_minutes)) &
                (phase_data['Minutes'] < (chaos_end - buffer_minutes))
            )
        else:  # after phase
            training_mask = phase_data['Minutes'] > (chaos_end + buffer_minutes)
        
        # Get training data for this phase (excluding borders)
        phase_training_data = phase_data[training_mask]
        
        if len(phase_training_data) < 5:
            outlier_stats[phase] = {
                'count': 0,
                'percentage': 0.0,
                'action': 'insufficient_training_data'
            }
            continue
        
        # Train on phase data excluding borders
        if len(numeric_cols) == 1:
            training_matrix = phase_training_data[numeric_cols[0]].values.reshape(-1, 1)
        else:
            training_matrix = phase_training_data[numeric_cols].values
        
        training_matrix = pd.DataFrame(training_matrix).fillna(method='ffill').fillna(method='bfill').values
        
        if np.std(training_matrix.flatten()) == 0:
            continue
        
        scaler = StandardScaler()
        training_matrix_scaled = scaler.fit_transform(training_matrix)
        
        # Train model on this phase's clean data
        contamination_rate = phase_contamination[phase]
        iso_forest = IsolationForest(
            contamination=contamination_rate,
            n_estimators=100,
            random_state=42,
            n_jobs=-1
        )
        
        iso_forest.fit(training_matrix_scaled)
        
        # Apply to ALL data in this phase
        if len(numeric_cols) == 1:
            phase_matrix = phase_data[numeric_cols[0]].values.reshape(-1, 1)
        else:
            phase_matrix = phase_data[numeric_cols].values
        
        phase_matrix = pd.DataFrame(phase_matrix).fillna(method='ffill').fillna(method='bfill').values
        phase_matrix_scaled = scaler.transform(phase_matrix)
        
        outlier_predictions = iso_forest.predict(phase_matrix_scaled)
        phase_outlier_mask = outlier_predictions == -1
        global_outlier_indices = phase_data.index[phase_outlier_mask]
        
        outlier_stats[phase] = {
            'count': phase_outlier_mask.sum(),
            'percentage': (phase_outlier_mask.sum() / len(phase_data)) * 100,
            'contamination_rate': contamination_rate,
            'training_points': len(phase_training_data),
            'excluded_border_minutes': buffer_minutes
        }
        
        total_outliers += phase_outlier_mask.sum()
        
        # Improved interpolation that preserves chaos patterns
        for col in numeric_cols:
            if phase_outlier_mask.sum() > 0:
                # Get the full phase data for this column
                phase_series = df_clean.loc[phase_mask, col].copy()
                outlier_indices_in_phase = phase_data.index[phase_outlier_mask]
                
                # Mark outliers as NaN in the phase series
                phase_series.loc[outlier_indices_in_phase] = np.nan
                
                if phase == 'during':
                    # During chaos: use more conservative interpolation
                    # Try to preserve the overall trend/pattern
                    try:
                        phase_series_interpolated = phase_series.interpolate(method='linear')
                    except:
                        phase_series_interpolated = phase_series.copy()
                    
                    # If linear doesn't work, try other methods
                    if phase_series_interpolated.isna().any():
                        try:
                            phase_series_interpolated = phase_series.interpolate(method='nearest')
                        except:
                            phase_series_interpolated = phase_series.copy()
                    
                    if phase_series_interpolated.isna().any():
                        phase_series_interpolated = phase_series.fillna(method='ffill').fillna(method='bfill')
                else:
                    # Before/after: can use more sophisticated interpolation
                    try:
                        phase_series_interpolated = phase_series.interpolate(method='polynomial', order=2)
                    except:
                        phase_series_interpolated = phase_series.interpolate(method='linear')
                    
                    if phase_series_interpolated.isna().any():
                        phase_series_interpolated = phase_series.interpolate(method='linear')
                    
                    if phase_series_interpolated.isna().any():
                        phase_series_interpolated = phase_series.fillna(method='ffill').fillna(method='bfill')
                
                # Update the main dataframe with interpolated values
                df_clean.loc[phase_mask, col] = phase_series_interpolated

    outlier_stats['_summary'] = {
        'total_outliers': total_outliers,
        'method': 'phase_aware_border_excluded_isolation_forest'
    }
    
    return df_clean, outlier_stats

# APPLY OUTLIER CLEANING
print("=" * 80)
print("NETWORK LOSS ANALYSIS - CHAOS-PRESERVING ISOLATION FOREST")
print("=" * 80)

datasets_clean = {}
all_outlier_stats = {}

for dataset_name, dataset_pair in original_datasets.items():
    print(f"\n📊 Processing {dataset_name}:")
    
    datasets_clean[dataset_name] = {}
    all_outlier_stats[dataset_name] = {}
    
    for source_type, df in dataset_pair.items():
        print(f"  🔍 {source_type.upper()}:")
        
        if source_type == 'baseline':
            df_clean, stats = remove_outliers_simple(df, contamination=0.02)
            total_outliers = stats['_summary']['total_outliers']
            print(f"    ✅ Global IF: Cleaned {total_outliers} outliers (2% contamination)")
        else:
            df_clean, stats = remove_outliers_phase_aware(df, delay, duration)
            total_outliers = stats['_summary']['total_outliers']
            print(f"    ✅ Phase-Aware IF (Chaos-Preserving): Cleaned {total_outliers} outliers")
            
            for phase in ['before', 'during', 'after']:
                if phase in stats:
                    phase_stats = stats[phase]
                    if 'action' in phase_stats:
                        print(f"      {phase}: {phase_stats['action']}")
                    else:
                        training_pts = phase_stats.get('training_points', 'N/A')
                        contamination = phase_stats.get('contamination_rate', 'N/A')
                        print(f"      {phase}: {phase_stats['count']} outliers ({phase_stats['percentage']:.1f}%, {contamination:.1%} contamination, {training_pts} training points)")
        
        datasets_clean[dataset_name][source_type] = df_clean
        all_outlier_stats[dataset_name][source_type] = stats

def normalize_df_memory(df, columns):
    result = df.copy()
    for col in columns:
        min_val = df[col].min()
        max_val = df[col].max()
        if max_val > min_val:  
            result[col] = (df[col] - min_val) / (max_val - min_val)
        else:
            result[col] = 0
    return result

def analyze_and_plot_memory_dataset_wide(dataset_name, netloss_df, baseline_df, delay_minutes, duration_minutes):
    numeric_cols = [col for col in netloss_df.select_dtypes(include=[np.number]).columns 
                   if col not in ['Time', 'Minutes']]
    
    netloss_norm = normalize_df_memory(netloss_df, numeric_cols)
    baseline_norm = normalize_df_memory(baseline_df, numeric_cols)
    
    main_metric = numeric_cols[0] if numeric_cols else None
    
    if main_metric is None:
        print(f"No numeric columns found for {dataset_name}")
        return None
    
    if 'phase' not in netloss_norm.columns:
        netloss_norm = add_phase_column(netloss_norm, delay_minutes, duration_minutes)
    if 'phase' not in baseline_norm.columns:
        baseline_norm = add_phase_column(baseline_norm, delay_minutes, duration_minutes)
    
    stats_baseline = baseline_norm.groupby('phase')[main_metric].agg(['mean', 'std', 'min', 'max'])
    stats_netloss = netloss_norm.groupby('phase')[main_metric].agg(['mean', 'std', 'min', 'max'])
    
    df_combined = pd.DataFrame({
        'Baseline': baseline_norm[main_metric],
        'NETLOSS': netloss_norm[main_metric],
        'Minutes': baseline_norm['Minutes'],
        'phase': baseline_norm['phase'],
        'difference': netloss_norm[main_metric] - baseline_norm[main_metric]
    })
    
    t_tests = {}
    for phase in ['before', 'during', 'after']:
        data = df_combined[df_combined['phase'] == phase]
        if len(data) > 1:
            t_stat, p_value = scipy_stats.ttest_ind(data['Baseline'].dropna(), data['NETLOSS'].dropna())
            t_tests[phase] = {'t': t_stat, 'p': p_value}
    
    impact = {}
    for phase in ['before', 'during', 'after']:
        if phase in stats_baseline.index:
            baseline_mean = stats_baseline.loc[phase, 'mean']
            netloss_mean = stats_netloss.loc[phase, 'mean']
            impact[phase] = ((netloss_mean - baseline_mean) / baseline_mean) * 100 if baseline_mean != 0 else float('inf')
    
    # PLOTTING
    fig = plt.figure(figsize=(24, 12))
    
    # 1. Baseline cleaning effect
    plt.subplot(2, 3, 1)
    original_baseline = original_datasets[dataset_name]['baseline']
    
    plt.plot(original_baseline['Minutes'], original_baseline[main_metric], 
             label='Original', color='orange', alpha=0.7, linewidth=1)
    plt.plot(baseline_df['Minutes'], baseline_df[main_metric], 
             label='Global IF Cleaned', linewidth=3, color='blue')
    plt.title(f'{dataset_name}: Baseline Cleaning', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel(f'{main_metric}', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 2. Network loss cleaning effect
    plt.subplot(2, 3, 2)
    original_netloss = original_datasets[dataset_name]['netloss']
    
    plt.plot(original_netloss['Minutes'], original_netloss[main_metric], 
             label='Original', alpha=0.7, color='lightcoral', linewidth=1)
    plt.plot(netloss_df['Minutes'], netloss_df[main_metric], 
             label='Chaos-Preserving IF', linewidth=3, color='darkred')
    plt.title(f'{dataset_name}: Network Loss Cleaning', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel(f'{main_metric}', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 3. Timeline comparison
    plt.subplot(2, 3, 3)
    plt.plot(baseline_norm['Minutes'], baseline_norm[main_metric], 
             label='Baseline', linewidth=3, color='blue', alpha=0.9)
    plt.plot(netloss_norm['Minutes'], netloss_norm[main_metric], 
             label='Network Loss', linewidth=3, color='red', alpha=0.9)
    plt.axvspan(delay_minutes, delay_minutes + duration_minutes, 
                color='red', alpha=0.2, label="Network Loss Period")
    plt.title(f"{dataset_name}: Comparison", fontsize=14, fontweight='bold')
    plt.xlabel("Minutes", fontsize=12)
    plt.ylabel(f"Normalized {main_metric}", fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=10)
    
    # 4. Box plot by phase
    plt.subplot(2, 3, 4)
    box_data = pd.melt(df_combined[['Baseline', 'NETLOSS', 'phase']], 
                      id_vars=['phase'], var_name='source', value_name='value')
    sns.boxplot(x='phase', y='value', hue='source', data=box_data, ax=plt.gca())
    plt.title(f'{dataset_name}: Distribution by Phase', fontsize=14, fontweight='bold')
    plt.xlabel('Phase', fontsize=12)
    plt.ylabel('Normalized Values', fontsize=12)
    plt.grid(axis='y', alpha=0.3)
    plt.legend(fontsize=10)
    
    # 5. Statistics by phase
    plt.subplot(2, 3, 5)
    phases = ['before', 'during', 'after']
    x = np.arange(len(phases))
    width = 0.35
    
    bars1 = plt.bar(x - width/2, stats_baseline['mean'], width, label='Baseline', alpha=0.8, color='blue')
    bars2 = plt.bar(x + width/2, stats_netloss['mean'], width, label='Network Loss', alpha=0.8, color='red')
    
    plt.errorbar(x - width/2, stats_baseline['mean'], yerr=stats_baseline['std'], 
                fmt='none', ecolor='black', capsize=5, linewidth=2)
    plt.errorbar(x + width/2, stats_netloss['mean'], yerr=stats_netloss['std'], 
                fmt='none', ecolor='black', capsize=5, linewidth=2)
    
    plt.title(f'{dataset_name}: Average by Phase', fontsize=14, fontweight='bold')
    plt.xlabel('Phase', fontsize=12)
    plt.ylabel('Mean Values', fontsize=12)
    plt.xticks(x, phases)
    plt.legend(fontsize=10)
    plt.grid(axis='y', alpha=0.3)
    
    # 6. Difference over time
    plt.subplot(2, 3, 6)
    plt.plot(df_combined['Minutes'], df_combined['difference'], 
             color='purple', linewidth=2, alpha=0.8)
    plt.axhline(y=0, color='black', linestyle='-', alpha=0.5, linewidth=1)
    plt.axvspan(delay_minutes, delay_minutes + duration_minutes, 
                color='red', alpha=0.2)
    plt.title(f'{dataset_name}: Difference', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel('Network Loss - Baseline', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.suptitle(f'{dataset_name} Network Loss Analysis - Chaos-Preserving Isolation Forest', 
                fontsize=18, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.subplots_adjust(top=0.90)
    plt.show()
    
    print(f"\n{'='*60}")
    print(f"{dataset_name.upper()} - RESULTS")
    print(f"{'='*60}")
    
    print(f"\n📊 BASELINE STATISTICS:")
    print(stats_baseline.round(4))
    
    print(f"\n📊 NETWORK LOSS STATISTICS:")
    print(stats_netloss.round(4))
    
    print(f"\n🔬 SIGNIFICANCE TESTS:")
    for phase, test in t_tests.items():
        sig = "✅ SIGNIFICANT" if test['p'] < 0.05 else "❌ NOT SIGNIFICANT"
        print(f"  {phase.upper():8}: t={test['t']:6.2f}, p={test['p']:8.4f} ({sig})")
    
    print(f"\n📈 IMPACT (% CHANGE):")
    for phase, change in impact.items():
        direction = "↗️ INCREASE" if change > 0 else "↘️ DECREASE" if change < 0 else "→ NO CHANGE"
        print(f"  {phase.upper():8}: {change:+7.2f}% ({direction})")
    
    return {
        'stats_baseline': stats_baseline,
        'stats_netloss': stats_netloss,
        't_tests': t_tests,
        'impact': impact,
        'combined_data': df_combined,
        'main_metric': main_metric
    }

# RUN ANALYSIS 
print(f"\n{'='*60}")
print("NETWORK LOSS ANALYSIS")
print(f"{'='*60}")

analysis_results = {}

for dataset_name in datasets_clean.keys():
    print(f"\n🔄 Analyzing {dataset_name}...")
    
    netloss_clean = datasets_clean[dataset_name]['netloss']
    baseline_clean = datasets_clean[dataset_name]['baseline']
    
    analysis_results[dataset_name] = analyze_and_plot_memory_dataset_wide(
        dataset_name, 
        netloss_clean, 
        baseline_clean, 
        delay, 
        duration
    )

# SUMMARY
print(f"\n{'='*80}")
print("SUMMARY")
print(f"{'='*80}")

summary_table = []
for dataset_name, results in analysis_results.items():
    if results:
        for phase in ['before', 'during', 'after']:
            summary_table.append({
                'Memory_Metric': dataset_name,
                'Phase': phase,
                'Impact (%)': f"{results['impact'][phase]:+.1f}%",
                'P-Value': f"{results['t_tests'][phase]['p']:.4f}",
                'Significant': 'YES' if results['t_tests'][phase]['p'] < 0.05 else 'NO'
            })

if summary_table:
    summary_df = pd.DataFrame(summary_table)
    print(summary_df.to_string(index=False, col_space=12))

print(f"\n{'='*80}")
print("METHODOLOGY SUMMARY")
print(f"{'='*80}")
print("🔹 BASELINE: Global Isolation Forest (2% contamination)")
print("🔹 TEST DATA: Phase-Aware Isolation Forest with Chaos Preservation:")
print("   • BEFORE phase: 2% contamination, excludes 2min before chaos")
print("   • DURING phase: 0.1% contamination, linear interpolation preserves patterns")
print("   • AFTER phase: 3% contamination, polynomial interpolation for smoothness")
print("🔹 INTERPOLATION: Multi-level fallback (polynomial → linear → fill)")
print("🔹 KEY FEATURE: Chaos effects preserved through conservative detection & smart interpolation")
# Out:
# ...
# NETWORK LOSS ANALYSIS - CHAOS-PRESERVING ISOLATION FOREST
# ...
#
# 📊 Processing Memory Utilization:
#   🔍 NETLOSS:
#     ✅ Phase-Aware IF (Chaos-Preserving): Cleaned 4 outliers
#       before: 0 outliers (0.0%, 2.0% contamination, 112 training points)
#       during: 0 outliers (0.0%, 0.1% contamination, 183 training points)
#       after: 4 outliers (2.5%, 3.0% contamination, 152 training points)
#   🔍 BASELINE:
#     ✅ Global IF: Cleaned 8 outliers (2% contamination)
#
# 📊 Processing Memory Cache:
#   🔍 NETLOSS:
#     ✅ Phase-Aware IF (Chaos-Preserving): Cleaned 14 outliers
#       before: 3 outliers (2.5%, 2.0% contamination, 112 training points)
#       during: 0 outliers (0.0%, 0.1% contamination, 183 training points)
#       after: 11 outliers (6.9%, 3.0% contamination, 152 training points)
#   🔍 BASELINE:
#     ✅ Global IF: Cleaned 8 outliers (2% contamination)
#
# 📊 Processing Memory Available:
#   🔍 NETLOSS:
#     ✅ Phase-Aware IF (Chaos-Preserving): Cleaned 4 outliers
# ...
