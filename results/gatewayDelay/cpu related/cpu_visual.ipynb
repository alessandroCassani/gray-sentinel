# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as scipy_stats
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Load all datasets
df_iowait = pd.read_csv("cpu_iowait.csv")
df_cpu_irq = pd.read_csv("cpu_irq.csv")
df_system_msec = pd.read_csv("cpu_system_msec.csv")
df_user_msec = pd.read_csv("cpu_user_msec.csv")
df_cpu_util = pd.read_csv("cpu_util_per.csv")

df_baseline_iowait = pd.read_csv("../../baseline/cpu related/cpu_iowait.csv")
df_baseline_irq = pd.read_csv("../../baseline/cpu related/cpu_irq.csv")
df_baseline_system_msec = pd.read_csv("../../baseline/cpu related/cpu_system_msec.csv")
df_baseline_user_msec = pd.read_csv("../../baseline/cpu related/cpu_user_msec.csv")
df_baseline_util_per = pd.read_csv("../../baseline/cpu related/cpu_util_per.csv")

# Add source labels
df_iowait["source"] = "NETWORK DELAY STRESS"
df_cpu_irq["source"] = "NETWORK DELAY STRESS"
df_system_msec["source"] = "NETWORK DELAY STRESS"
df_user_msec["source"] = "NETWORK DELAY STRESS"
df_cpu_util["source"] = "NETWORK DELAY STRESS"

df_baseline_iowait["source"] = "BASELINE"
df_baseline_irq["source"] = "BASELINE"
df_baseline_system_msec["source"] = "BASELINE"
df_baseline_user_msec["source"] = "BASELINE"
df_baseline_util_per["source"] = "BASELINE"

# Convert to datetime
df_iowait["Time"] = pd.to_datetime(df_iowait["Time"])
df_cpu_irq["Time"] = pd.to_datetime(df_cpu_irq["Time"])
df_system_msec["Time"] = pd.to_datetime(df_system_msec["Time"])
df_user_msec["Time"] = pd.to_datetime(df_user_msec["Time"])
df_cpu_util["Time"] = pd.to_datetime(df_cpu_util["Time"])

df_baseline_iowait["Time"] = pd.to_datetime(df_baseline_iowait["Time"])
df_baseline_irq["Time"] = pd.to_datetime(df_baseline_irq["Time"])
df_baseline_system_msec["Time"] = pd.to_datetime(df_baseline_system_msec["Time"]) 
df_baseline_user_msec["Time"] = pd.to_datetime(df_baseline_user_msec["Time"])
df_baseline_util_per["Time"] = pd.to_datetime(df_baseline_util_per["Time"])

delay = 30
duration = 50

# Synchronize test datasets with baseline timeline
time_offset = df_baseline_iowait["Time"].min() - df_iowait["Time"].min()
df_iowait["Time"] += time_offset
df_cpu_irq["Time"] += time_offset
df_system_msec["Time"] += time_offset
df_user_msec["Time"] += time_offset
df_cpu_util["Time"] += time_offset

# Convert timeline to minutes 
all_dfs = [
    df_iowait, df_cpu_irq, df_system_msec, df_user_msec, df_cpu_util,
    df_baseline_iowait, df_baseline_irq, df_baseline_system_msec, 
    df_baseline_user_msec, df_baseline_util_per
]

for df in all_dfs:
    df["Minutes"] = (df["Time"] - df["Time"].min()).dt.total_seconds() / 60

# ORIGINAL DATASETS DICTIONARY 
original_datasets = {
    'IOWait': {'network_delay_stress': df_iowait, 'baseline': df_baseline_iowait},
    'IRQ': {'network_delay_stress': df_cpu_irq, 'baseline': df_baseline_irq},
    'System': {'network_delay_stress': df_system_msec, 'baseline': df_baseline_system_msec},
    'User': {'network_delay_stress': df_user_msec, 'baseline': df_baseline_user_msec},
    'Utilization': {'network_delay_stress': df_cpu_util, 'baseline': df_baseline_util_per}
}

# ADD PHASE COLUMN FUNCTION
def add_phase_column(df, delay_minutes, duration_minutes):
    df = df.copy()
    df['phase'] = 'before'  
    df.loc[(df['Minutes'] >= delay_minutes) & (df['Minutes'] <= delay_minutes + duration_minutes), 'phase'] = 'during'  
    df.loc[df['Minutes'] > delay_minutes + duration_minutes, 'phase'] = 'after' 
    return df

# GLOBAL ISOLATION FOREST FOR BASELINE (no chaos injected)
def remove_outliers_baseline_global(df, contamination=0.03):
    df_clean = df.copy()
    cpu_cols = [col for col in df.columns if col.startswith('cpu')]
    outlier_stats = {}
    
    if len(cpu_cols) == 0:
        return df_clean, outlier_stats
    
    feature_matrix = df[cpu_cols].values
    
    if np.isnan(feature_matrix).any():
        feature_matrix = pd.DataFrame(feature_matrix).fillna(method='ffill').fillna(method='bfill').values
    
    scaler = StandardScaler()
    try:
        feature_matrix_scaled = scaler.fit_transform(feature_matrix)
    except:
        feature_matrix_scaled = feature_matrix
    
    iso_forest = IsolationForest(
        contamination=contamination,
        n_estimators=100,
        random_state=42,
        n_jobs=-1
    )
    
    iso_forest.fit(feature_matrix_scaled)
    outlier_predictions = iso_forest.predict(feature_matrix_scaled)
    
    outlier_mask = outlier_predictions == -1
    
    for col in cpu_cols:
        outlier_stats[col] = {
            'count': outlier_mask.sum(),
            'percentage': (outlier_mask.sum() / len(df[col])) * 100
        }
        
        df_clean.loc[outlier_mask, col] = np.nan
        df_clean[col] = df_clean[col].interpolate(method='linear')

    outlier_stats['_summary'] = {
        'total_outliers': outlier_mask.sum(),
        'contamination_rate': contamination,
        'method': 'isolation_forest_global_baseline'
    }
    
    return df_clean, outlier_stats

# PER-PHASE ISOLATION FOREST FOR TEST DATA (chaos injected)
def remove_outliers_test_per_phase(df, delay_minutes=30, duration_minutes=50):
    df_clean = df.copy()
    df_clean = add_phase_column(df_clean, delay_minutes, duration_minutes)
    
    cpu_cols = [col for col in df.columns if col.startswith('cpu')]
    outlier_stats = {}
    
    if len(cpu_cols) == 0:
        return df_clean, outlier_stats
    
    phase_contamination = {
        'before': 0.03,
        'during': 0.08,
        'after': 0.05
    }
    
    total_outliers = 0
    
    for phase in ['before', 'during', 'after']:
        phase_mask = df_clean['phase'] == phase
        phase_data = df_clean[phase_mask]
        
        if len(phase_data) < 10:
            continue
            
        feature_matrix = phase_data[cpu_cols].values
        
        if np.isnan(feature_matrix).any():
            feature_matrix = pd.DataFrame(feature_matrix).fillna(method='ffill').fillna(method='bfill').values
        
        if np.std(feature_matrix.flatten()) == 0:
            continue
        
        scaler = StandardScaler()
        try:
            feature_matrix_scaled = scaler.fit_transform(feature_matrix)
        except:
            feature_matrix_scaled = feature_matrix
        
        contamination_rate = phase_contamination[phase]
        iso_forest = IsolationForest(
            contamination=contamination_rate,
            n_estimators=100,
            random_state=42,
            n_jobs=-1
        )
        
        iso_forest.fit(feature_matrix_scaled)
        outlier_predictions = iso_forest.predict(feature_matrix_scaled)
        
        phase_outlier_mask = outlier_predictions == -1
        global_outlier_indices = phase_data.index[phase_outlier_mask]
        
        outlier_stats[phase] = {
            'count': phase_outlier_mask.sum(),
            'percentage': (phase_outlier_mask.sum() / len(phase_data)) * 100,
            'contamination_rate': contamination_rate
        }
        
        total_outliers += phase_outlier_mask.sum()
        
        for col in cpu_cols:
            df_clean.loc[global_outlier_indices, col] = np.nan
            phase_data_col = df_clean.loc[phase_mask, col]
            df_clean.loc[phase_mask, col] = phase_data_col.interpolate(method='linear')

    outlier_stats['_summary'] = {
        'total_outliers': total_outliers,
        'method': 'isolation_forest_per_phase_test'
    }
    
    return df_clean, outlier_stats

# APPLY HYBRID OUTLIER CLEANING
datasets_clean = {}
all_outlier_stats = {}

for dataset_name, dataset_pair in original_datasets.items():
    print(f"\n📊 Processing {dataset_name} with Hybrid Isolation Forest:")
    
    datasets_clean[dataset_name] = {}
    all_outlier_stats[dataset_name] = {}
    
    for source_type, df in dataset_pair.items():
        print(f"  🔍 {source_type.upper().replace('_', ' ')}:")
        
        if source_type == 'baseline':
            # Apply global IF for baseline (no chaos phases)
            df_clean, stats = remove_outliers_baseline_global(df, contamination=0.03)
            total_outliers = stats['_summary']['total_outliers']
            print(f"    ✅ Global IF: Cleaned {total_outliers} outliers (3% contamination)")
            
        else:
            # Apply per-phase IF for test data (with chaos phases)
            df_clean, stats = remove_outliers_test_per_phase(df, 
                                                           delay_minutes=delay, 
                                                           duration_minutes=duration)
            total_outliers = stats['_summary']['total_outliers']
            print(f"    ✅ Per-Phase IF: Cleaned {total_outliers} outliers across all phases")
            
            for phase in ['before', 'during', 'after']:
                if phase in stats:
                    phase_stats = stats[phase]
                    print(f"      {phase}: {phase_stats['count']} outliers ({phase_stats['percentage']:.1f}%)")
        
        datasets_clean[dataset_name][source_type] = df_clean
        all_outlier_stats[dataset_name][source_type] = stats

# NORMALIZATION FUNCTION
def normalize_df(df, columns):
    result = df.copy()
    for col in columns:
        min_val = df[col].min()
        max_val = df[col].max()
        if max_val > min_val:  
            result[col] = (df[col] - min_val) / (max_val - min_val)
        else:
            result[col] = 0
    return result

# ANALYSIS AND PLOT FUNCTION
def analyze_and_plot_dataset_wide(dataset_name, network_delay_stress_df, baseline_df, delay_minutes, duration_minutes):
    cpu_cols = [col for col in network_delay_stress_df.columns if col.startswith('cpu')]
    
    network_delay_stress_norm = normalize_df(network_delay_stress_df, cpu_cols)
    baseline_norm = normalize_df(baseline_df, cpu_cols)
    
    network_delay_stress_df['Total'] = network_delay_stress_df[cpu_cols].sum(axis=1)
    baseline_df['Total'] = baseline_df[cpu_cols].sum(axis=1)
    
    network_delay_stress_norm['Total'] = (network_delay_stress_df['Total'] - network_delay_stress_df['Total'].min()) / (network_delay_stress_df['Total'].max() - network_delay_stress_df['Total'].min())
    baseline_norm['Total'] = (baseline_df['Total'] - baseline_df['Total'].min()) / (baseline_df['Total'].max() - baseline_df['Total'].min())
    
    if 'phase' not in network_delay_stress_norm.columns:
        network_delay_stress_norm = add_phase_column(network_delay_stress_norm, delay_minutes, duration_minutes)
    if 'phase' not in baseline_norm.columns:
        baseline_norm = add_phase_column(baseline_norm, delay_minutes, duration_minutes)
    
    stats_baseline = baseline_norm.groupby('phase')['Total'].agg(['mean', 'std', 'min', 'max'])
    stats_network_delay_stress = network_delay_stress_norm.groupby('phase')['Total'].agg(['mean', 'std', 'min', 'max'])
    
    df_combined = pd.DataFrame({
        'Baseline': baseline_norm['Total'],
        'NETWORK_DELAY_STRESS': network_delay_stress_norm['Total'],
        'Minutes': baseline_norm['Minutes'],
        'phase': baseline_norm['phase'],
        'difference': network_delay_stress_norm['Total'] - baseline_norm['Total']
    })
    
    t_tests = {}
    for phase in ['before', 'during', 'after']:
        data = df_combined[df_combined['phase'] == phase]
        if len(data) > 1:
            t_stat, p_value = scipy_stats.ttest_ind(data['Baseline'].dropna(), data['NETWORK_DELAY_STRESS'].dropna())
            t_tests[phase] = {'t': t_stat, 'p': p_value}
    
    impact = {}
    for phase in ['before', 'during', 'after']:
        if phase in stats_baseline.index:
            baseline_mean = stats_baseline.loc[phase, 'mean']
            network_delay_stress_mean = stats_network_delay_stress.loc[phase, 'mean']
            impact[phase] = ((network_delay_stress_mean - baseline_mean) / baseline_mean) * 100 if baseline_mean != 0 else float('inf')
    
    fig = plt.figure(figsize=(24, 12))
    
    # 1. Baseline outlier cleaning effect
    plt.subplot(2, 3, 1)
    original_baseline = original_datasets[dataset_name]['baseline']
    
    plt.plot(original_baseline['Minutes'], original_baseline[cpu_cols].sum(axis=1), 
             label='Baseline (with outliers)', color='orange', alpha=0.7, linewidth=1)
    plt.plot(baseline_df['Minutes'], baseline_df['Total'], 
             label='Baseline (Global IF cleaned)', linewidth=3, color='blue')
    plt.title(f'{dataset_name}: Baseline Global IF Cleaning', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel(f'Total {dataset_name}', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 2. NETWORK DELAY STRESS outlier cleaning effect
    plt.subplot(2, 3, 2)
    original_network_delay_stress = original_datasets[dataset_name]['network_delay_stress']
    
    plt.plot(original_network_delay_stress['Minutes'], original_network_delay_stress[cpu_cols].sum(axis=1), 
             label='NETWORK DELAY STRESS (with outliers)', alpha=0.7, color='lightcoral', linewidth=1)
    plt.plot(network_delay_stress_df['Minutes'], network_delay_stress_df['Total'], 
             label='NETWORK DELAY STRESS (Per-Phase IF cleaned)', linewidth=3, color='darkred')
    plt.title(f'{dataset_name}: NETWORK DELAY STRESS Per-Phase IF Cleaning', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel(f'Total {dataset_name}', fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    
    # 3. Timeline comparison
    plt.subplot(2, 3, 3)
    plt.plot(baseline_norm['Minutes'], baseline_norm['Total'], 
             label='Baseline (Global IF)', linewidth=3, color='blue', alpha=0.9)
    plt.plot(network_delay_stress_norm['Minutes'], network_delay_stress_norm['Total'], 
             label='NETWORK DELAY STRESS (Per-Phase IF)', linewidth=3, color='red', alpha=0.9)
    plt.axvspan(delay_minutes, delay_minutes + duration_minutes, 
                color='red', alpha=0.2, label="Network Delay Stress Period")
    plt.title(f"{dataset_name}: Hybrid IF Comparison", fontsize=14, fontweight='bold')
    plt.xlabel("Minutes", fontsize=12)
    plt.ylabel(f"Normalized {dataset_name}", fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize=10)
    
    # 4. Box plot by phase
    plt.subplot(2, 3, 4)
    box_data = pd.melt(df_combined[['Baseline', 'NETWORK_DELAY_STRESS', 'phase']], 
                      id_vars=['phase'], var_name='source', value_name='value')
    sns.boxplot(x='phase', y='value', hue='source', data=box_data, ax=plt.gca())
    plt.title(f'{dataset_name}: Distribution by Phase', fontsize=14, fontweight='bold')
    plt.xlabel('Phase', fontsize=12)
    plt.ylabel('Normalized Values', fontsize=12)
    plt.grid(axis='y', alpha=0.3)
    plt.legend(fontsize=10)
    
    # 5. Statistics by phase
    plt.subplot(2, 3, 5)
    phases = ['before', 'during', 'after']
    x = np.arange(len(phases))
    width = 0.35
    
    bars1 = plt.bar(x - width/2, stats_baseline['mean'], width, label='Baseline (Global IF)', alpha=0.8, color='blue')
    bars2 = plt.bar(x + width/2, stats_network_delay_stress['mean'], width, label='NETWORK DELAY STRESS (Per-Phase IF)', alpha=0.8, color='red')
    
    plt.errorbar(x - width/2, stats_baseline['mean'], yerr=stats_baseline['std'], 
                fmt='none', ecolor='black', capsize=5, linewidth=2)
    plt.errorbar(x + width/2, stats_network_delay_stress['mean'], yerr=stats_network_delay_stress['std'], 
                fmt='none', ecolor='black', capsize=5, linewidth=2)
    
    plt.title(f'{dataset_name}: Average by Phase', fontsize=14, fontweight='bold')
    plt.xlabel('Phase', fontsize=12)
    plt.ylabel('Mean Normalized Values', fontsize=12)
    plt.xticks(x, phases)
    plt.legend(fontsize=10)
    plt.grid(axis='y', alpha=0.3)
    
    # 6. Difference over time
    plt.subplot(2, 3, 6)
    plt.plot(df_combined['Minutes'], df_combined['difference'], 
             color='purple', linewidth=2, alpha=0.8)
    plt.axhline(y=0, color='black', linestyle='-', alpha=0.5, linewidth=1)
    plt.axvspan(delay_minutes, delay_minutes + duration_minutes, 
                color='red', alpha=0.2)
    plt.title(f'{dataset_name}: Difference (Hybrid IF)', fontsize=14, fontweight='bold')
    plt.xlabel('Minutes', fontsize=12)
    plt.ylabel('NETWORK DELAY STRESS - Baseline', fontsize=12)
    plt.grid(True, alpha=0.3)
    
    plt.suptitle(f'{dataset_name} Network Delay Stress Analysis - Hybrid Isolation Forest', 
                fontsize=18, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.subplots_adjust(top=0.90)
    plt.show()
    
    print(f"\n{'='*80}")
    print(f"{dataset_name.upper()} - HYBRID IF NETWORK DELAY STRESS ANALYSIS RESULTS")
    print(f"{'='*80}")
    
    print(f"\n📊 BASELINE STATISTICS BY PHASE (Global IF):")
    print(stats_baseline.round(4))
    
    print(f"\n📊 NETWORK DELAY STRESS STATISTICS BY PHASE (Per-Phase IF):")
    print(stats_network_delay_stress.round(4))
    
    print(f"\n🔬 STATISTICAL SIGNIFICANCE TESTS:")
    for phase, test in t_tests.items():
        sig = "✅ SIGNIFICANT" if test['p'] < 0.05 else "❌ NOT SIGNIFICANT"
        print(f"  {phase.upper():8}: t={test['t']:6.2f}, p={test['p']:8.4f} ({sig})")
    
    print(f"\n📈 NETWORK DELAY STRESS IMPACT (% CHANGE):")
    for phase, change in impact.items():
        direction = "↗️ INCREASE" if change > 0 else "↘️ DECREASE" if change < 0 else "→ NO CHANGE"
        print(f"  {phase.upper():8}: {change:+7.2f}% ({direction})")
    
    return {
        'stats_baseline': stats_baseline,
        'stats_network_delay_stress': stats_network_delay_stress,
        't_tests': t_tests,
        'impact': impact,
        'combined_data': df_combined
    }

# RUN ANALYSIS 
print(f"\n{'='*80}")
print("COMPREHENSIVE NETWORK DELAY STRESS ANALYSIS - HYBRID ISOLATION FOREST")
print(f"{'='*80}")
print("🔹 BASELINE: Global Isolation Forest (no phases)")
print("🔹 TEST DATA: Per-Phase Isolation Forest (context-aware)")

analysis_results = {}

for dataset_name in datasets_clean.keys():
    print(f"\n🔄 Analyzing {dataset_name}...")
    
    network_delay_stress_clean = datasets_clean[dataset_name]['network_delay_stress']
    baseline_clean = datasets_clean[dataset_name]['baseline']
    
    analysis_results[dataset_name] = analyze_and_plot_dataset_wide(
        dataset_name, 
        network_delay_stress_clean, 
        baseline_clean, 
        delay, 
        duration
    )
# Out:
# 📊 Processing IOWait with Hybrid Isolation Forest:
#   🔍 NETWORK DELAY STRESS:
#     ✅ Per-Phase IF: Cleaned 27 outliers across all phases
#       before: 4 outliers (3.3%)
#       during: 15 outliers (7.5%)
#       after: 8 outliers (4.8%)
#   🔍 BASELINE:
#     ✅ Global IF: Cleaned 12 outliers (3% contamination)
#
# 📊 Processing IRQ with Hybrid Isolation Forest:
#   🔍 NETWORK DELAY STRESS:
#     ✅ Per-Phase IF: Cleaned 26 outliers across all phases
#       before: 4 outliers (3.3%)
#       during: 16 outliers (8.0%)
#       after: 6 outliers (3.6%)
#   🔍 BASELINE:
#     ✅ Global IF: Cleaned 14 outliers (3% contamination)
#
# 📊 Processing System with Hybrid Isolation Forest:
#   🔍 NETWORK DELAY STRESS:
#     ✅ Per-Phase IF: Cleaned 25 outliers across all phases
#       before: 4 outliers (3.3%)
#       during: 15 outliers (7.5%)
#       after: 6 outliers (3.6%)
#   🔍 BASELINE:
#     ✅ Global IF: Cleaned 12 outliers (3% contamination)
#
# ...
